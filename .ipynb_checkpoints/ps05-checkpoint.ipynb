# %%
## Replace this with your name and Section

# %% [markdown]
# DS 256 Data Science Programming, Fall 2024
#
# Prof Eatai Roth
#
# ## Problem Set 5
# Due 11/14/2024 by 8p

# %% [markdown]
# ## Titanic Pandas
# (sounds cute...is not)
#
# In this assignment, we'll explore the titanic training data set. These data represent a portion of the passenger manifest of the Titanic, detailing the passengers and whether or not they survived the fateful crash.
#
# The columns are mostly self-explanatory. Key to less-obvious columns:
#  - Sex - male=1 / female=0
#  - Parch - number of parents/children traveling with
#  - SibSp - numbers of siblings/spouses traveling with
#  - PClass - ticket class (like first class, business, economy)
#
#
#  To start, you should import packages, ```pandas``` (as pd) and ```matplotlib.pyplot``` (as plt). Then load the data from ```titanic_train_clean.csv``` into a pandas dataframe.
#
#  Feel free to add more code blocks if needed. When making figures, don't forget to label axes and provide titles and legends when appropriate.

# %%
# Add the boilerplate code for importing the required packages and data
import pandas as pd
import matplotlib.pyplot as plt

t_df=pd.read_csv('titanic.csv')

# %% [markdown]
# ## Homework Problems
#
# For each of the problems, you'll write some code to find the answer. If there is a written/short answer component, use the provided text field.

# %% [markdown]
# ### Problem 1
#
#  - How many passengers are recorded in this log?
#  - What percentage are male?
#  - What percentage survived?
#
# Hint: You can find these three answers with a single command.

# %%
'''your code here'''
t_df.describe()
# Out:
#               Age        Fare       Parch  PassengerId      Pclass  \
# count  891.000000  891.000000  891.000000   891.000000  891.000000
# mean    29.445196   32.204208    0.381594   446.000000    2.308642
# std     13.244896   49.693429    0.806057   257.353842    0.836071
# min      0.420000    0.000000    0.000000     1.000000    1.000000
# 25%     22.000000    7.910400    0.000000   223.500000    2.000000
# 50%     30.000000   14.454200    0.000000   446.000000    3.000000
# 75%     35.500000   31.000000    0.000000   668.500000    3.000000
# max     80.000000  512.329200    6.000000   891.000000    3.000000
#
#               Sex       SibSp    Survived  Family_Size
# count  891.000000  891.000000  891.000000   891.000000
# mean     0.647587    0.523008    0.383838     0.904602
# std      0.477990    1.102743    0.486592     1.613459
# min      0.000000    0.000000    0.000000     0.000000
# 25%      0.000000    0.000000    0.000000     0.000000
# ...

# %% [markdown]
# Your written answer:
#
#  - There are 891 passengers recorded in this log.
#  - 64.8% of passengers are male.
#  - 38.4% of passengers survived.

# %% [markdown]
# ### Problem 2:
#
#  - What percentage of female passengers survived?
#  - What percentage of male passengers survived?

# %%
'''your code here'''
t_df_male = t_df[t_df['Sex'] == 1]
t_df_female = t_df[t_df['Sex'] == 0]
t_df_male.describe()
# Out:
#               Age        Fare       Parch  PassengerId      Pclass    Sex  \
# count  577.000000  577.000000  577.000000   577.000000  577.000000  577.0
# mean    30.423172   25.523893    0.235702   454.147314    2.389948    1.0
# std     13.214580   43.138263    0.612294   257.486139    0.813580    0.0
# min      0.420000    0.000000    0.000000     1.000000    1.000000    1.0
# 25%     23.000000    7.895800    0.000000   222.000000    2.000000    1.0
# 50%     30.000000   10.500000    0.000000   464.000000    3.000000    1.0
# 75%     36.000000   26.550000    0.000000   680.000000    3.000000    1.0
# max     80.000000  512.329200    5.000000   891.000000    3.000000    1.0
#
#             SibSp    Survived  Family_Size
# count  577.000000  577.000000   577.000000
# mean     0.429809    0.188908     0.665511
# std      1.061811    0.391775     1.478106
# min      0.000000    0.000000     0.000000
# 25%      0.000000    0.000000     0.000000
# ...

# %%
t_df_female.describe()
# Out:
#               Age        Fare       Parch  PassengerId      Pclass    Sex  \
# count  314.000000  314.000000  314.000000   314.000000  314.000000  314.0
# mean    27.648089   44.479818    0.649682   431.028662    2.159236    0.0
# std     13.132434   57.997698    1.022846   256.846324    0.857290    0.0
# min      0.750000    6.750000    0.000000     2.000000    1.000000    0.0
# 25%     21.000000   12.071875    0.000000   231.750000    1.000000    0.0
# 50%     25.000000   23.000000    0.000000   414.500000    2.000000    0.0
# 75%     35.500000   55.000000    1.000000   641.250000    3.000000    0.0
# max     63.000000  512.329200    6.000000   889.000000    3.000000    0.0
#
#             SibSp    Survived  Family_Size
# count  314.000000  314.000000   314.000000
# mean     0.694268    0.742038     1.343949
# std      1.156520    0.438211     1.755733
# min      0.000000    0.000000     0.000000
# 25%      0.000000    0.000000     0.000000
# ...

# %% [markdown]
# Your written answer:
#
#  - 74.2% of female passengers survived.
#  - 18.9% of male passengers survived.

# %% [markdown]
# ### Problem 3
#
# Use ```groupby``` and ```agg``` to find the percentage of the total tickets and the survivorship percentage for each class of ticket.

# %%
'''your code here'''
t_df_survived = t_df.groupby(['Pclass', 'Survived']).agg({'Survived': 'sum'})
t_df_class = t_df.groupby(['Pclass']).agg({'Pclass': 'count'})
t_df_class['ticket_percent'] = t_df_class/t_df_class.agg('sum')
t_df_class
# Out:
#         Pclass  ticket_percent
# Pclass
# 1          216        0.242424
# 2          184        0.206510
# 3          491        0.551066

# %%
t_df_survived['Pclass_Count'] = [216, 216, 184, 184, 491, 491]
t_df_survived['Pclass_Survived'] = t_df_survived['Survived']/t_df_survived['Pclass_Count']
t_df_survived
# Out:
#                  Survived  Pclass_Count  Pclass_Survived
# Pclass Survived
# 1      0                0           216         0.000000
#        1              136           216         0.629630
# 2      0                0           184         0.000000
#        1               87           184         0.472826
# 3      0                0           491         0.000000
#        1              119           491         0.242363

# %% [markdown]
# Your written answer:
#
#  - Class 1
#     - % tickets: 24.2
#     - % survivorship: 63.0
# - Class 2
#     - % tickets: 20.7
#     - % survivorship: 47.3
# - Class 3
#     - % tickets: 55.1
#     - % survivorship: 24.2

# %% [markdown]
# ### Problem 4
#
# Create two new dataframes corresponding to survivors and non-survivors keeping only the columns: age, name, and sex. Display the first five rows of these new dataframes.
#
# Create a figure showing the distribution of age by sex and survivorship (four histograms on the same axes: male-survivors, female-survivors, male-unlucky, female-unlucky). Choose colors and histtype (see the [documentation for histogram](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html)) to make this figure easy to read and interpret.

# %%
'''Your code here'''
t_df_survived = t_df[t_df['Survived'] == 1]
t_df_died = t_df[t_df['Survived'] == 0]
t_df_died = t_df_died[['Age', 'Name', 'Sex']]
t_df_survived = t_df_survived[['Age', 'Name', 'Sex']]

t_df_survived_male = t_df_survived[t_df_survived['Sex'] == 1]
t_df_survived_female = t_df_survived[t_df_survived['Sex'] == 0]
t_df_died_male = t_df_died[t_df_died['Sex'] == 1]
t_df_died_female = t_df_died[t_df_died['Sex'] == 0]

# %%
#GRADE THIS ONE

fig, ax = plt.subplots(1,1, figsize = (4,4), sharex = True, sharey = True)
plot_opts = dict(bins = 10,
                 alpha = 0.4)
plt.hist(t_df_survived_male['Age'], **plot_opts, label = 'Male Survivors', color = '#1266d9')
plt.hist(t_df_survived_female['Age'], **plot_opts, label = 'Female Survivors', color = '#d91212')
plt.hist(t_df_died_male['Age'], **plot_opts, label = 'Male Fatalities', color = '#12b8d9')
plt.hist(t_df_died_female['Age'], **plot_opts, label = 'Female Fatalities', color = '#d912a0')
ax.legend()
ax.set_xlabel('Age')
ax.set_ylabel('Number of Individuals')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Problem 5
#
# Now that we've inspected the data, let's build a classifier (you'll compare two models) that predicts which passengers survived. These are the steps you should take:
#
#  - Choose your features. The label will be survivorship.
#  - Split the data into training and test sets.
#  - Standardize the values using StandardScaler
#  - Choose two of the following model types: KNN, SVM, Decision Tree. Create those models and select hyper-parameters.
#  - Fit your models to the training data.
#  - Apply the fit models to create predictions from the test data.
#  - For each model, create a confusion matrix for the training and test data. You may want to revisit the hyper-parameters and re-fit the models.
#
#  - Answer the questions at the bottom of the code block.

# %%
def plotDecisionBoundary(model, data = None, xy_lim = None, ax = None):

    import matplotlib.pyplot as plt
    import numpy as np
    
    if ax is None:
        fig, ax = plt.subplots(1,1, figsize = (5,5))
    else:
        fig = ax.get_figure()
    
    # Check if data or xy_lim is provided
    if data is None and xy_lim is None:
        raise ValueError('If data is None, xy_lim must be provided')
    elif xy_lim is not None:
        f0_min, f0_max, f1_min, f1_max = xy_lim[0][0], xy_lim[0][1], xy_lim[1][0], xy_lim[1][1]
    elif not data is None:
        X = data[0]
        y = data[1]
        f0_min, f0_max, f1_min, f1_max = min(X[:,0]), max(X[:,0]), min(X[:,1]), max(X[:,1])

    range0, range1 = f0_max-f0_min, f1_max-f1_min

    F0, F1 = np.meshgrid(np.linspace(f0_min-0.1*range0, f0_max+0.1*range0, 200), np.linspace(f1_min-0.1*range1, f1_max+0.1*range1, 200))
    F_grid = np.vstack([F0.ravel(), F1.ravel()]).transpose()

    labels = model.classes_
    label_nums = np.arange(len(labels))
    label_dict = dict(zip(labels, label_nums))

    y_grid = model.predict(F_grid)
    y_num_grid = np.array([label_dict[y_lab] for y_lab in y_grid]).reshape(F0.shape)

    cmap = plt.get_cmap('tab10', len(labels))
    ax.contourf(F0, F1, y_num_grid, cmap = cmap, alpha = 0.25)

    if not data is None:
        for label, label_num in zip(labels, label_nums):
            ax.scatter(X[y==label,0], X[y==label,1], label = label, s = 10, alpha = 0.75)
        ax.legend()
    plt.show()

    ax.set_xlabel('Feature 0')
    ax.set_ylabel('Feature 1')
    ax.set_aspect('equal')
    return fig, ax

# %%
'''Your code here'''
features = ['Age', 'Sex']
label = ['Survived']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(t_df[features], t_df[label], test_size = 0.2)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

ss = StandardScaler()
ss.fit(X_train)
Xs_train = ss.transform(X_train)
Xs_test = ss.transform(X_test)
ys_train = y_train.values.ravel()
ys_test = y_test.values.ravel()

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_clf = KNeighborsClassifier(n_neighbors = 5)
knn_clf.fit(Xs_train, ys_train)

fig, ax = plotDecisionBoundary(knn_clf, data = (Xs_train, ys_train))

# %%
from sklearn.svm import SVC

svc_clf = SVC(kernel='rbf', gamma = 5)
svc_clf.fit(Xs_train, ys_train)

fig, ax = plotDecisionBoundary(svc_clf, data = (Xs_train, ys_train))

# %%
from sklearn.metrics import ConfusionMatrixDisplay


fig, ax = plt.subplots(1,2, figsize = (15,4))

y_knn_train = knn_clf.predict(Xs_train)
y_knn_test = knn_clf.predict(Xs_test)

y_svc_train = svc_clf.predict(Xs_train)
y_svc_test = svc_clf.predict(Xs_test)

ConfusionMatrixDisplay.from_predictions(y_train, y_knn_train, display_labels = ['Survived', 'Did not'], 
                                               normalize = 'true', 
                                               cmap = 'Greens',
                                               ax = ax[0])
ConfusionMatrixDisplay.from_predictions(y_train, y_svc_train, display_labels = ['Survived', 'Did not'], 
                                               normalize = 'true', 
                                               cmap = 'Greens',
                                               ax = ax[1])

fig.suptitle('Confusion Matrix from Training Data')
ax[0].set_title('KNN')
ax[1].set_title('SVM')
# Out:
# Text(0.5, 1.0, 'SVM')

# %%
fig, ax = plt.subplots(1,2, figsize = (15,4))

ConfusionMatrixDisplay.from_predictions(y_test, y_knn_test, display_labels = ['Survived', 'Did not'], 
                                               normalize = 'true', 
                                               cmap = 'Greens',
                                               ax = ax[0])

ConfusionMatrixDisplay.from_predictions(y_test, y_svc_test, display_labels = ['Survived', 'Did not'], 
                                               normalize = 'true', 
                                               cmap = 'Greens',
                                               ax = ax[1])

fig.suptitle('Confusion Matrix from Testing Data')
ax[0].set_title('KNN')
ax[1].set_title('SVM')
# Out:
# Text(0.5, 1.0, 'SVM')

# %% [markdown]
# #### **Questions**
#
# How does the model performance on the test data compare to the performance on the training data?
#
#  - The test data for the KNN is very close in quality to the training data. The training predicted survival with 84% accuracy and death with 72% accuracy, while the test predicted survival with 83% accuratacy and death with 76% accuracy. The test data for the SVM is actually slightly better than the training data, with over 80% prediction rate for each.
#
#
# Which models did you fit and which worked better?
#
#  - I used KNN and SVM, SVM seems to predict with slightly better accuracy, though they both are around 80%.
